# %%
from app.inat_net import INATNet
from helpers.utils import get_model_info
from app.trainer import Trainer
from app.data import DataManager
from app.config import Config
from app.inference_engine import InferenceEngine
from app.model_manager import ModelManager
from torch.utils.data import DataLoader
from app.data import SteganalysisDataset

# %%
model = INATNet(num_classes=2)
get_model_info(model)

config = Config.load('configs/experiment_config.json')
model_manager = ModelManager()
loaded_model = model_manager.load_model(model, "/Users/dmitryhoma/Projects/phd_dissertation/state_3/INATNet/models/inatnet_v1_20251031_134512.pth")

inference_engine = InferenceEngine(model, config)
prediction, probabilities = inference_engine.predict_single("stego_image.png")
print(f"Prediction: {'Stego' if prediction == 1 else 'Cover'}")
print(f"Probabilities: {probabilities}")

prediction, probabilities = inference_engine.predict_single("cover_image.png")
print(f"Prediction: {'Stego' if prediction == 1 else 'Cover'}")
print(f"Probabilities: {probabilities}")
# Out:
# ============================================================
# INATNet
# ============================================================
#
# Trainable parameters: 12,811,177
# Total parameters: 12,813,427
# Frozen (SRM) parameters: 2,250
#
# ============================================================
# Architecture highlights:
# ============================================================
# ✓ 30 SRM high-pass filters (frozen)
# ✓ TLU + Absolute Value layer
# ✓ Deep residual architecture
# ✓ Separable convolutions for efficiency
# ✓ Inception attention block near the end
# ✓ All 4 attention mechanisms (SE, CBAM, GC, Triplet)
# ============================================================
# Model loaded from /Users/dmitryhoma/Projects/phd_dissertation/state_3/INATNet/models/inatnet_v1_20251031_134512.pth
# Prediction: Cover
# Probabilities: [0.92688125 0.07311877]
# Prediction: Cover
# Probabilities: [0.927085   0.07291504]

# %%
# Setup
config = Config.load('configs/experiment_config.json')
model = INATNet(num_classes=2)

# Load best model
trainer = Trainer(model, config, experiment_name="evaluation")
trainer.load_checkpoint("models/inatnet_v1_20251031_134512.pth")

# Create test dataloader
data_manager = DataManager(config)

test_dataset = SteganalysisDataset(
    cover_dir="data/custom_big/test/cover",
    stego_dir="data/custom_big/test/stego",
    transform=data_manager.transform_val
)
test_loader = DataLoader(test_dataset, batch_size=config.batch_size, shuffle=False)

# Evaluate
test_metrics = trainer.validate(test_loader)

# Display results
print("\nTest Set Results:")
print("-" * 70)
print(f"Accuracy:  {test_metrics['val_acc']:.2f}%")
print(f"Precision: {test_metrics['val_precision']:.2f}%")
print(f"Recall:    {test_metrics['val_recall']:.2f}%")
print(f"F1 Score:  {test_metrics['val_f1']:.2f}%")
print(f"Loss:      {test_metrics['val_loss']:.4f}")
print("-" * 70)
# Out:
# 2025-10-31 15:00:45,279 [INFO] Initialized trainer for evaluation
# 2025-10-31 15:00:45,280 [INFO] Using device: cpu
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 7
#       5 # Load best model
#       6 trainer = Trainer(model, config, experiment_name="evaluation")
# ----> 7 trainer.load_checkpoint("models/inatnet_v1_20251031_134512.pth")
#       9 # Create test dataloader
#      10 data_manager = DataManager(config)
#
# File ~/Projects/phd_dissertation/state_3/INATNet/app/trainer.py:299, in Trainer.load_checkpoint(self, filepath)
#     296 checkpoint = torch.load(filepath, map_location=self.device)
#     298 self.model.load_state_dict(checkpoint['model_state_dict'])
# --> 299 self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     301 if 'scheduler_state_dict' in checkpoint and self.scheduler:
#     302     self.scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
#
# KeyError: 'optimizer_state_dict'
